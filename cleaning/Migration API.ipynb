# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
url = "https://open.alberta.ca/dataset/eece1571-4b82-40be-8a11-4627db1a9561/resource/2acfe7ec-6c54-48ea-bcb8-6aa72fd64a7a/download/rows"
response = requests.get(url).json()
#pprint (response)

# %%
#pprint (response['data'][6])
net_migration =[]
time_period = []
for index in range(0,831,3):
    net_migration.append(response['data'][index][12])

for index in range(0,831,3):
    time_period.append((response['data'][index][8].split("-01",1)[0]))

# %%
#Create Dataframe
migration_df = pd.DataFrame({"Date": time_period,"National Net Migration": net_migration})

migration_df["National Net Migration"] = pd.to_numeric(migration_df["National Net Migration"])
# Out:
#         Date  National Net Migration
# 0    1946-03                   12738
# 1    1946-06                   21176
# 2    1946-09                   25078
# 3    1946-12                   12727
# 4    1947-03                    8009
# 5    1947-06                   13404
# 6    1947-09                   18624
# 7    1947-12                   24090
# 8    1948-03                   23076
# 9    1948-06                   34199
# 10   1948-09                   33932
# 11   1948-12                   34207
# 12   1949-03                   23265
# 13   1949-06                   30243
# 14   1949-09                   22641
# 15   1949-12                   19068
# 16   1950-03                   14470
# 17   1950-06                   22816
# 18   1950-09                   16964
# 19   1950-12                   19662
# 20   1951-03                   25914
# 21   1951-06                   53871
# 22   1951-09                   36463
# 23   1951-12                   50869
# 24   1952-03                   29106
# 25   1952-06                   40629
# 26   1952-09                   20676
# 27   1952-12                   13528
# 28   1953-03                   10387
# 29   1953-06                   42306
# ..       ...                     ...
# 247  2007-12                   26513
# 248  2008-03                   58364
# 249  2008-06                   90807
# 250  2008-09                   89890
# 251  2008-12                   33606
# 252  2009-03                   65141
# 253  2009-06                   86895
# 254  2009-09                   91491
# 255  2009-12                   28729
# 256  2010-03                   61556
# 257  2010-06                   87008
# 258  2010-09                   93793
# 259  2010-12                   13066
# 260  2011-03                   48786
# 261  2011-06                   79307
# 262  2011-09                   85696
# 263  2011-12                   36645
# 264  2012-03                   58198
# 265  2012-06                   94532
# 266  2012-09                   85760
# 267  2012-12                   24600
# 268  2013-03                   62013
# 269  2013-06                   98919
# 270  2013-09                   92518
# 271  2013-12                   16356
# 272  2014-03                   58516
# 273  2014-06                   89534
# 274  2014-09                   93514
# 275  2014-12                    -419
# 276  2015-03                   27697
#
# [277 rows x 2 columns]

# %%
#Create line graph
plt.figure(figsize=(30,10))
plt.plot(migration_df["Date"],migration_df["National Net Migration"])
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
# Push the remade DataFrame to a new CSV file
migration_df.to_csv('../cleaning/nationalmigration_clean.csv',
                  index=False, header=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-30080dc9be9a> in <module>
#       1 # Push the remade DataFrame to a new CSV file
#       2 migration_df.to_csv('..cleaning/nationalmigration_clean.csv',
# ----> 3                   index=False, header=True)
#
# ~/miniconda3/envs/machine_learning/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~/miniconda3/envs/machine_learning/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     163                 f, handles = _get_handle(path_or_buf, self.mode,
#     164                                          encoding=encoding,
# --> 165                                          compression=self.compression)
#     166                 f.write(buf)
#     167                 f.close()
#
# ~/miniconda3/envs/machine_learning/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '..cleaning/nationalmigration_clean.csv'
