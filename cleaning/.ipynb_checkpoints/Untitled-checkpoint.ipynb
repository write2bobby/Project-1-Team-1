# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint

# %%
url = "https://open.alberta.ca/dataset/4a493355-1283-4197-9928-7bb7baa01939/resource/a5f6d8a4-ed6f-42ca-8c59-fdaf31b306ab/download/rows.json"
response = requests.get(url).json()
pprint (response['data'])
# Out:
# [[6448,
#   '7F2B6726-9616-43E0-9C34-A7889807B549',
#   6448,
#   1435604684,
#   '710753',
#   1435604684,
#   '710753',
#   None,
#   '1997-01-01T00:00:00',
#   'Chained (2007) dollars',
#   'Public administration',
#   '7269000000',
#   '8762000000',
#   None,
#   '3325000000',
#   '2203000000',
#   '1620000000',
#   '3606000000',
#   '30306000000',
#   '461000000',
#   '16111000000',
#   '2349000000'],
#  [6447,
#   'E95EBBBE-4F32-497E-83F3-187D8D12A590',
#   6447,
#   1435604684,
#   '710753',
#   1435604684,
#   '710753',
#   None,
#   '1997-01-01T00:00:00',
#   'Chained (2007) dollars',
#   'Other services (except public administration)',
#   '2479000000',
#   '2977000000',
#   None,
#   '726000000',
#   '390000000',
#   '268000000',
#   '470000000',
#   '7558000000',
#   '85000000',
#   '4382000000',
#   '633000000'],
#  [6446,
#   '067D1786-1621-425D-A773-D160F1AEB077',
#   6446,
#   1435604684,
#   '710753',
#   1435604684,
#   '710753',
#   None,
# ...
