# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
migration_data = pd.read_csv('../resources/newnationalmigration_clean.csv')
migration_data.head()
# Out:
#    Date  National Net Migration
# 0  1946                   71719
# 1  1947                   64127
# 2  1948                  125414
# 3  1949                   95217
# 4  1950                   73912

# %%
fig, axes = plt.subplots()
axes.plot(migration_data['Date'], migration_data['National Net Migration'])
axes.set(title='National Net Migration Into Canada', xlabel='Date', ylabel = 'Net Migration')
# Out:
# [Text(0,0.5,'Net Migration'),
#  Text(0.5,0,'Date'),
#  Text(0.5,1,'National Net Migration Into Canada')]
