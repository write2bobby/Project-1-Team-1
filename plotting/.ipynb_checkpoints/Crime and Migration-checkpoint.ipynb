# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
migration_data = pd.read_csv('../resources/newnationalmigration_clean.csv')
total_crime_data = pd.read_csv('../resources/TotalCrimeCanada.csv')
migration_data = migration_data[(migration_data['Date'] >= 1962) & (migration_data['Date'] <= 2000)]
# Out:
#     Date  National Net Migration
# 0   1946                   71719
# 1   1947                   64127
# 2   1948                  125414
# 3   1949                   95217
# 4   1950                   73912
# 5   1951                  167117
# 6   1952                  103939
# 7   1953                  110893
# 8   1954                   97077
# 9   1955                   48053
# 10  1956                   96104
# 11  1957                  207781
# 12  1958                   63170
# 13  1959                   37739
# 14  1960                   28515
# 15  1961                    -616
# 16  1962                   -2154
# 17  1963                    9588
# 18  1964                   20176
# 19  1965                   41451
# 20  1966                  103254
# 21  1967                  114414
# 22  1968                   83938
# 23  1969                   71442
# 24  1970                   66752
# 25  1971                   72966
# 26  1972                   98806
# ...

# %%
total_crime_data
# Out:
#           Date  Total Crime Incidences
# 0       796675                    1962
# 264     874572                    1963
# 528     960917                    1964
# 792     989451                    1965
# 1056   1094889                    1966
# 1320   1188704                    1967
# 1584   1335444                    1968
# 1848   1470760                    1969
# 2112   1574223                    1970
# 2376   1648818                    1971
# 2640   1650230                    1972
# 2904   1809135                    1973
# 3168   2009886                    1974
# 3432   2132507                    1975
# 3696   2182777                    1976
# 3960   2226605                    1977
# 4266   2305968                    1978
# 4572   2485630                    1979
# 4878   2692158                    1980
# 5184   2850060                    1981
# 5490   2838837                    1982
# 5796   2249244                    1983
# 6219   2239493                    1984
# ...

# %%
relevant_crime_data = total_crime_data[total_crime_data['Date'] == migration_data['Date']]
relevant_crime_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-1f9fe872a34b> in <module>
# ----> 1 relevant_crime_data = total_crime_data[total_crime_data['Date'] == migration_data['Date']]
#       2 relevant_crime_data.head()
#
# ~/miniconda3/envs/machine_learning/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1188
#    1189         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1190             raise ValueError("Can only compare identically-labeled "
#    1191                              "Series objects")
#    1192
#
# ValueError: Can only compare identically-labeled Series objects
